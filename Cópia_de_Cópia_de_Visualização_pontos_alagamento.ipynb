# %% [markdown]
# ##CÓDIGO PARA USAR NO TCC - NOVA RUSSAS ALAGAMENTOS

# %%
import folium
import webbrowser

# Coordenadas dos pontos
latitude = [-4.7066128, -4.7106770, -4.6998637, -4.7107441, -4.7043402, -4.7114298, -4.7077101, -4.7096488, -4.7097778, -4.7000976, -4.7104504, -4.6993026, -4.7117499]  # Exemplo de latitude dos pontos
longitude = [-40.5637218, -40.5585153, -40.5527436, -40.5579239, -40.5550553, -40.5584473, -40.5635177, -40.5627063, -40.5650039, -40.5527791, -40.5578927, -40.5549446, -40.5601149]  # Exemplo de longitude dos pontos

# Rótulos dos pontos
labels = ["Av. Joaquim Lopes Pedrosa", "AV. Zilmar Mendes Martins", "Estr.Cachoeira", "R. Anastácio R de Carvalho", "R. Davi José de Carvalho", "R. Evaristo de Castro", "R. Helvécio Moura", "R. Joaquim Onófre", "R. José Rosa", "R. Maria Clarice Tavares", "R. Maria do Socorro da Silva", "R. Raimundo Matias de Sousa", "R. Antônio Pereira de Sousa"]  # Exemplo de rótulos dos pontos

# Criar um mapa centrado em uma localização específica
mapa = folium.Map(location=[-4.706635333181908, -40.56269287589916], zoom_start=16)

# Adicionar marcadores de pontos no mapa
#folium.Marker([-5.171336055324488, -40.65808177283075], popup='IFCE-Campus Crateús').add_to(mapa)
#folium.Marker([-5.186521272817921, -40.64467553770283], popup='UFC-Campus Crateús').add_to(mapa)
#folium.Marker([-5.17656365281711, -40.67816657592246], popup='FAEC-UECE-Campus Crateús').add_to(mapa)

# Adicionar um círculo em volta de um ponto específico
folium.CircleMarker([-4.7066128, -40.5637218], radius=10, color='red', fill_color='red').add_to(mapa)
folium.CircleMarker([-4.7106770, -40.5585153], radius=10, color='red', fill_color='red').add_to(mapa)
folium.CircleMarker([-4.6998637, -40.5527436], radius=10, color='red', fill_color='red').add_to(mapa)
folium.CircleMarker([-4.7107441, -40.5579239], radius=10, color='red', fill_color='red').add_to(mapa)
folium.CircleMarker([-4.7043402, -40.5550553], radius=10, color='red', fill_color='red').add_to(mapa)
folium.CircleMarker([-4.7114298, -40.5584473], radius=10, color='red', fill_color='red').add_to(mapa)
folium.CircleMarker([-4.7077101, -40.5635177], radius=10, color='red', fill_color='red').add_to(mapa)
folium.CircleMarker([-4.7096488, -40.5627063], radius=10, color='red', fill_color='red').add_to(mapa)
folium.CircleMarker([-4.7097778, -40.5650039], radius=10, color='red', fill_color='red').add_to(mapa)
folium.CircleMarker([-4.7000976, -40.5527791], radius=10, color='red', fill_color='red').add_to(mapa)
folium.CircleMarker([-4.7104504, -40.5578927], radius=10, color='red', fill_color='red').add_to(mapa)
folium.CircleMarker([-4.6993026, -40.5549446], radius=10, color='red', fill_color='red').add_to(mapa)
folium.CircleMarker([-4.7117499, -40.5601149], radius=10, color='red', fill_color='red').add_to(mapa)

# Links dos vídeos ou fotos associados aos pontos
video_links = [
    "https://drive.google.com/file/d/1OCHkhbOrtTSRTRVlsHFzeFOFmC0yQ-37/view",
    "https://drive.google.com/file/d/1kq2D2SltgHVRdbR4LWCSdb-ME0qev8e4/view",
    "https://drive.google.com/file/d/1cv9aj-eu_ZliWrpV4Kmlk0u-M8YhteRS/view",
    "https://drive.google.com/file/d/11_BhK8RUNSIiMy2l9fRNhY1prxgAvnuF/view",
    "https://drive.google.com/file/d/1y2_pqBhtygBxIj_nIuzBRRccFCFVd0oU/view",
    "https://drive.google.com/file/d/1fw5sNQa4WAz5msnfrczudf42ZS8m3fi8/view",
    "https://drive.google.com/file/d/1r6egcszIc5P0zd1mgKDJgxW94xBmIFQT/view",
    "https://drive.google.com/file/d/1Sl_x11qdkoAIYTGIrLP3Tj6kVEAzhDor/view",
    "https://drive.google.com/file/d/1ngdBy5-uGmlpRdNSYOdRQrztjp8o8sj7/view",
    "https://drive.google.com/file/d/1e367F4I5q7LepM693k5OQMjBgGRvCUXp/view",
    "https://drive.google.com/file/d/1FcZFR6bSxyvs0S_aPMj_dYvq5PhF_3fI/view",
    "https://drive.google.com/file/d/182_r733tRuX8lrsVGyM6Kv4ddvnm_Qm5/view",
    "https://drive.google.com/file/d/12fQ7ARLH_QAcVnZ8OpZjqqZ04qRIcbb3/view"
]

# Adiciona marcadores, pop-ups e rótulos para cada ponto
for lat, lng, link, label in zip(latitude, longitude, video_links, labels):
    popup = folium.Popup(f"<a href='{link}'>Link para o vídeo</a>", max_width=300)
    folium.Marker(location=[lat, lng], popup=popup, tooltip=label).add_to(mapa)


# Salvar o mapa como um arquivo HTML
mapa.save('NOVA_RUSSAS.html')
